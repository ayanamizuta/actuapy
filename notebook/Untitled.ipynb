# %%
import pandas as pd
import os,sys

# %%
from actuary.core import LifeTable

# %%
test_data_path = "/Users/mizutarei/cpro/Sandbox/actuary/package/actuary/tests/data/"
df = pd.read_csv(test_data_path+"core_lifetable.csv",dtype={0:str})
df.set_index('Unnamed: 0',inplace=True)
lt = LifeTable(df,datatype="lifetable")

# %%
lt.plot_quit_trend()
